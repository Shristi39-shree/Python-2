# %%
import pandas as pd 
from io import StringIO
data ='{"emplyee_name":"Shristi","email":"shristijha39@gmail.com","job_profile":[{"title1":"Team lead","title2":"Sr.Developer"}]}'
df = pd.read_json(StringIO(data))

# %%
df
# Out:
#   emplyee_name                   email  \
# 0      Shristi  shristijha39@gmail.com
#
#                                          job_profile
# 0  {'title1': 'Team lead', 'title2': 'Sr.Developer'}

# %%
df.to_json()
# Out:
# '{"emplyee_name":{"0":"Shristi"},"email":{"0":"shristijha39@gmail.com"},"job_profile":{"0":{"title1":"Team lead","title2":"Sr.Developer"}}}'

# %%
df.to_json(orient='index')
# Out:
# '{"0":{"emplyee_name":"Shristi","email":"shristijha39@gmail.com","job_profile":{"title1":"Team lead","title2":"Sr.Developer"}}}'

# %%
df.to_json(orient='records')
# Out:
# '[{"emplyee_name":"Shristi","email":"shristijha39@gmail.com","job_profile":{"title1":"Team lead","title2":"Sr.Developer"}}]'

# %%
pd.read_csv("WineQT.csv")
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.to_csv("wine.csv")

# %%
# !pip install lxml

# %%
url="https://gist.github.com/lillylangtree/b55828fa05ed3470d352"

df=pd.read_html(url)

# %%
df
# Out:
# [     0                                                  1
#  0  NaN                                    <!DOCTYPE html>
#  1  NaN                                                NaN
#  2  NaN                                             <html>
#  3  NaN                                             <head>
#  4  NaN  <meta http-equiv="Content-Type" content="text/...
#  5  NaN                         <title>Spoon-Knife</title>
#  6  NaN  <LINK href="styles.css" rel="stylesheet" type=...
#  7  NaN                                            </head>
#  8  NaN                                                NaN
#  9  NaN                                             <body>
#  10 NaN                                                NaN
#  11 NaN       <img src="forkit.gif" id="octocat" alt="" />
#  12 NaN                                                NaN
#  13 NaN        <!-- Feel free to change this text here -->
#  14 NaN                                                <p>
# ...

# %%
df[0]
# Out:
#      0                                                  1
# 0  NaN                                    <!DOCTYPE html>
# 1  NaN                                                NaN
# 2  NaN                                             <html>
# 3  NaN                                             <head>
# 4  NaN  <meta http-equiv="Content-Type" content="text/...
# 5  NaN                         <title>Spoon-Knife</title>
# 6  NaN  <LINK href="styles.css" rel="stylesheet" type=...
# 7  NaN                                            </head>
# 8  NaN                                                NaN
# 9  NaN                                             <body>
# 10 NaN                                                NaN
# 11 NaN       <img src="forkit.gif" id="octocat" alt="" />
# 12 NaN                                                NaN
# 13 NaN        <!-- Feel free to change this text here -->
# 14 NaN                                                <p>
# ...

# %%
df_excel=pd.read_excel('data.xlsx')

# %%
df_excel.topickle('df_excel')

# %%
pd.read_pickle('df_excel')
