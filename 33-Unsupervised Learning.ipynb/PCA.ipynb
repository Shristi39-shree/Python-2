# %% [markdown]
# ### Principle component Analysis(Dimensionality Reduction)
#
# * (1)Curse of Dimensionality
# * Dataset:-500 Features
#
# M1--> 3 Features
#
# M2--> 6 Features
#
# M3--> 15 Features
#
# M4--> 50 Features(Model is overfeeded)
#
# M5--> 100Features
#
# M6--> 500 Features
# * M1(Acc 1) > M2(Acc 2++) > M3(Acc3+++) < M4(Acc4--) < M5(Acc 5---) < M6(Acc6----)
#
# * (2)Model Performance Degrade
#
# #### Two different ways to remove curse of dimensionality
# * (1) Feature Selection-->Important features are being selceted to avoid the overfitting of the model
# * (2) Dimensionality Reduction(PCA)-->Feature extraction--> Derive the features d1 and d2 from the features f1,f2,f3,f4
