# %% [markdown]
# ## Supervised Learning
# Dataset-f1 f2 f3 f4 (input),
# o/p - DEpendent or o/p features.
# * Two types of problem statement we were solving:
# Regression and classification
#
# ## Unsupervised Learning
# Clustering(Group oue data into similar cluster)
#
# #### Algorithm:
# * K - Means
# * Hirerchial Clustering
# * DBScan Clustering
# * Silhoutte Scoring
