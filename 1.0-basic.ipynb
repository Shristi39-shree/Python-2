# %% [markdown]
# ### Syntax
# Syntax refers to the set of rules that defines the combinations of symbols that are considered to be correctly structured program in a language.In simpler terms ,syntax is about the correct arrangement of words and symbols in a code.
#
#
# Semantics refers to the meaning or the interpretation of the symbols ,characters and commands in a language .It is about what the code is supposed to do when it runs.

# %%
## Basic Syntax Rules in Python
## case sensitivity -Python( is case sensitive

name ="Shristi"
Name = "Jha"

print(name)
print(Name)
# Out:
# Shristi
# Jha

# %% [markdown]
# ### Indentation
# Indentation in Python is used to define the structure and hierrarchy of the code.Unlike many other programming languages that use braces{} to delimit blocks of code,Python uses indentation to determine the grouping of statments .This means that all the statements within a block must be indented at the same level.

# %%
##Indentation
## Python usesindentation to define blocks of code.Consistent use of spaces(commonly 4) or a tab is required

age = 21
if age>18:
   
   print(age)

print(age)
# Out:
# 21
# 21

# %%
## This is a single line comment
print("HEllo World")
# Out:
# HEllo World

# %%
## LIne continuation

total=1+2+3+4+5+6+\
4+5+6

print(total)
# Out:
# 36

# %%
## Multiple statement on a single line
x=5;y=1;z=x+y
print(z)
# Out:
# 6

# %%
##Understand Semantics in Python
# variable assignment
age = 30 ## age is a integer
name ="Ashu" ##name is a string

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
##Type Inference
variable = 10
print(type(variable))
variable="Ashu"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age = 10
if age>8:
  print(age)
# Out:
# 10

# %%
##Name Error
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 ##Name Error
# ----> 2 a=b
#
# NameError: name 'b' is not defined

# %%
##Code examples of indentation
if True:
  print("Correct Indentation")
  if False:
    print("This ont print")
  print("print")  
print("Outside the if block")
# Out:
# Correct Indentation
# print
# Outside the if block
