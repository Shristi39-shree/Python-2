# %% [markdown]
# ### Program
# A program is a sequence of instructions written in programming language[E.g:-Python,C++]
#
# E.g:- Googlr Chrome -->.exe <--> Program -->  Browser should work
#
# WORD,EXCEL
#
# ### Process
#  A process is simply an instance of a program that is being executed.
#
#  |Code segment| Data segment|Heap|
#
#  |Stack           | Registers    |
#
#  SEPARATE MEMORY SPACE:- One process cannot corrupt another process.
#
#  I/O REQUIREMENTS:- Increased execution time to switch  between processes.
#
#  E.g:- BROWSER,
#
#        EXCEL--> process-->Id
#        App--> Process
#
# #### Thread
# A thread is a unit of execution within a process.
#
# SINGLE THREADED PROCESS:
#
# |Code segment| Data segment|Heap|
#
# |Stack           | Registers    |
#
# |                   S           |
#
#
#  MULTI THREADED PROCESS:
#
#  |Code segment| Data segment|Heap|
#
#  |Stack           | Registers    |
#
#  |       S        |     S        |
#
#
# E.g:- MS Paint-->Process--> rectangle,circle
