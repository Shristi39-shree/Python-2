# %%
## if statement
age = 20
if age>=18:
   print("You are allowed to vote")
# Out:
# You are allowed to vote

# %%
## else
## The else statement executes a block of code if then condition in the if statement is False.

age = 16
 
if age>=18:
    print("You are eligible for voting")

else:
     print("Not eligible")
# Out:
# Not eligible

# %%
## elif
## The elif statement allows you to check multiple conditions.It stands for "else if"

age =20

if age<13:
   print("You are child")
elif age>18:
  print("You are teenager")
else:
  print("You are an adult")
# Out:
# You are teenager

# %%
## Nested Conditional Statements

# You can place one or more if,elif ,or else statements inside another if,elif ,or else statement create nested conditional statements.

## number even,odd,negative

num = int(input("Enter the number"))

if num>0:
  print("Number is positive")
  if num%2==0:
    print("The number is Even")
  else:
    print("The number is odd ")

else:
  print("The number is negative or zero")
# Out:
# The number is negative or zero

# %%
## Practical Examples

## Determine if a year is a leap year using nested condition statement

## number even ,odd,negative

year=int(input("Enter the year"))

if year%4==0:
  if year%100==0:
    if year%400==0:
      print(year,"is a leap year")
    else:
      print(year,"is not a leap year")
  else:
      print(year,"is leap year")
else:
    print(year,"is not a leap year")
# Out:
# 2024 is leap year

# %%
## Assignmnet
## Simple Calculator program
num1 = float(input("Enter the 1st number"))
num2 =float (input("Enter the 2nd number"))
operator = input("Enter the operator you want to use  (+,-,*,/):")

if operator == '+':
  Sum = num1 + num2
  print(Sum)
elif operator == '-':
   Diff = num1 -num2
   print(Diff)
elif operator == '*':
    Mul = num1*num2
    print(Mul)
elif operator =='/':
    Div = num1/num2
    print(Div)
else :
   print("Invalid Input")   
    

  ## We can use same variable Result for all operations and print it at last,instead of writing mul div,diff and sum(*Beginner coder)

# %%
## Determine the ticket price based on age and whether the person is a student

age = int(input("Enter your age"))
Stu = input("Are you a student:(yes/no)").lower()

if age <12:
  print("As you are under age ,ticket price for you is :$10")
elif age >=18 :
  print("Ticket price for adult is : $50")
  if Stu=='Yes':
   print("Discount for student ,Ticket price:$35")
else:
  print("Invalid input ")
# Out:
# Ticket price for adult is : $50
