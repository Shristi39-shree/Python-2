# %% [markdown]
# ### Standard Library Overview
#
# Python's Standard Library is a vast collection of modules and packages that come bundled with Python,providing a wide range of functionalities out of the box.Here's an overview of some of the most commonly used modules and packages in the Python Standard Library.

# %%
import array
arr = array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## random

import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 5
# cherry

# %%
### File And Directory Access

import os
print(os.getcwd())
# Out:
# c:\Users\KIIT0001\OneDrive\Documents\Desktop\Python2\5-Modules

# %%
os.mkdir('test_dir')

# %%
### create any empty file

open("empty.txt","w").close()

# %%
## High level operations on files and collection of files
import shutil
shutil.copyfile('empty.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serialization
import json
data={'name':'Shristi','age':21}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Shristi", "age": 21}
# <class 'str'>
# {'name': 'Shristi', 'age': 21}
# <class 'dict'>

# %%
## CSV 
import csv 

## Write mode
with open('example.csv',mode='w',newline='') as file:
 writer = csv.writer(file)
 writer.writerow(['name','age'])
 writer.writerow(['Shristi',21])

 ## Read mode

with open('example.csv',mode='r') as file:
  reader=csv.reader(file)
  for row in reader:
    print(row)
# Out:
# ['name', 'age']
# ['Shristi', '21']

# %%
## datetime
from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday = now - timedelta()
print(yesterday)
# Out:
# 2026-01-12 20:32:46.213305
# 2026-01-12 20:32:46.213305

# %%
## time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1768230246.3333797
# 1768230248.334422

# %%
## Regular Expression
import re
pattern=r'\d+'
text='There are 100 bananas'
match=re.search(pattern,text)
print(match.group())
# Out:
# 100

# %% [markdown]
# ### Conclusion
#
# Python's Standard Library is extensive and provides tools for almost any task you can think of,from file handling to web services,from data serialization to concurrent execution.Familiarizing yourself with the modules and packages available in the Standard Library can significantly enhance your ability to write efficient and effective Python programs.
