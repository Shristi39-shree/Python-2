# %% [markdown]
# #### Introduction of Tuples
#
# ##### Explanation:
#
#  #### Tuples are ordered collections of items that are immutable .they are similar to lists ,but their immutability makes them different.

# %%
## creating a tuple
empty_tuple=()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst = list()
print(type(lst))

tpl= tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
numbers=tuple([1,2,3,4,5,6])
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
list((1,2,3,4,5,6))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
mixed_tuple=(1,"Hello World",3.14,True)
print(mixed_tuple)
# Out:
# (1, 'Hello World', 3.14, True)

# %%
## Accessing Tuple Elements

numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
print(numbers[0])
print(numbers[-1])
# Out:
# 1
# 6

# %%
numbers[0:4]
# Out:
# (1, 2, 3, 4)

# %%
numbers[::-1]
# Out:
# (6, 5, 4, 3, 2, 1)

# %%
## Tuple Operations

concatenation_tuple=numbers + mixed_tuple
print(concatenation_tuple)
# Out:
# (1, 2, 3, 4, 5, 6, 1, 'Hello World', 3.14, True)

# %%
mixed_tuple*3   ## get displayed 3 times
# Out:
# (1,
#  'Hello World',
#  3.14,
#  True,
#  1,
#  'Hello World',
#  3.14,
#  True,
#  1,
#  'Hello World',
#  3.14,
#  True)

# %%
numbers*3
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)

# %%
## Immutable nature of tuples
## Tuples are immutable,meaning their elements cannot be changed once assigned.

lst=[1,2,3,4,5]
print(lst)

lst[1] = "Shristi"
print(lst)
# Out:
# [1, 2, 3, 4, 5]
# [1, 'Shristi', 3, 4, 5]

# %%
tuples=(1,2,3,4,5)
print(tuples)

tuples(1) = "Shree"    ## Cannot change the element
print(tuples)
# Out:
#   Cell In[19], line 4
#     tuples(1) = "Shree"
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
## Tuple Methods
print(tuples.count(1))
print(tuples.index(3))
# Out:
# 1
# 2

# %%
## Packing and Unpacking tuple
## Packing
packed_tuple = 1,"Hello",3.2
print(packed_tuple)
# Out:
# (1, 'Hello', 3.2)

# %%
## unpacking a tuple
a,b,c = packed_tuple
print(a)
print(b)
print(c)
# Out:
# 1
# Hello
# 3.2

# %%
## Unpacking with *
numbers = (1,2,3,4,5,6)
first,*middle,last=numbers
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
## Nested Tuple
## Nested List
lst = [[1,2,3,],[2,5,6.12],[7,8,"shree"]]
lst[0][2]
lst[0][0:3]    ## slicing operation
# Out:
# [1, 2, 3]

# %%
nested_tuple = ((1,2,3),("a","b","c"),(True,False))

## access the elements inside a tuple
print(nested_tuple[0])
print(nested_tuple[1][2])
# Out:
# (1, 2, 3)
# c

# %%
## iterating over nested tuples
for sub_tuple in nested_tuple:
  for item in sub_tuple:
    print(item,end=" ")
  print()
# Out:
# 1 2 3
# a b c
# True False

# %% [markdown]
# ### Conclusion
#
# Tuples are versatile and useful in many real-world scenarios where an immutable and ordered collection of items is required.They are commonly used in data structures,function arguments and return values,and as dictionary keys.Understanding how to leverage tuples effectively can improve the efficiency and reliability of our Python code.
