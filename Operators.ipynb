# %%
## Arithmetic Operation

a = 10
b = 5

add_result = a+b #addition
sub = a-b #substraction
mul = a*b # Multiplication
div = a/b # Division
floor_div = a//b # floor division
modulas_result = a%b # modulus operation

exponent_result = a**b # Exponentiation

print(add_result)
print(sub)
print(mul)
print(div)
print(floor_div)
print(modulas_result)
print(exponent_result)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %% [markdown]
# ### Comparision Operators

# %%
## ==
a = 10
b = 90

a==b
# Out:
# False

# %%
str1 = "shree"
str2 = "sh"

str1 == str2
# Out:
# False

# %%
## Not equal to  !=
str1 !=str2
# Out:
# True

# %%
str3 = "Ram"
str4 = "ram"

str3 == str4
# Out:
# False

# %%
## Greater than >
num1 = 70
num2 = 80
num1>num2
# Out:
# False

# %%
#less than <
num3 = 9
num4 = 10

num3<num4
# Out:
# True

# %%
#greater than or equal to 
n = 20
m = 9

n >=m
# Out:
# True

# %%
#less than or equal
n<=m
# Out:
# False

# %% [markdown]
# ### Logical Operators

# %%
## And ,Not ,OR
X = True 
Y = True

result = X and Y
print(result)
# Out:
# True

# %%
# Not operator
X = True
not X
# Out:
# False

# %%
# Or operator
result = X or Y
print(result)
# Out:
# True
