# %% [markdown]
# * WSGI-->Web Server Gateway Interface
# * Jinja 2 Template Engine
#
# ##### Flask:-- WEb framework which is created with the Python programming language.
#
# * WEB SERVER --> AWS EC2,Azure App,Apache,lls
#    |
#    |
#   WEB App(when requests come to web server it redirect to the web app and get the response back)

# %% [markdown]
# * Protocol like WSGI is being used to connct to web app

# %% [markdown]
# ##### Jinja 2 Template Engine:-
# * WEb tamplate Engine:-Combines a web templates with a datasource(SQL DR,CSv SHeet,ML Model,Mongodb)
